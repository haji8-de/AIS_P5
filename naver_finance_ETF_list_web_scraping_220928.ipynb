# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import requests
from datetime import datetime

# %%
def ETF_list_scraping():
    today = datetime.today().strftime("%Y-%m-%d")
    print(today + "의 ETP 정보입니다.")

    url = "https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc"

    response = requests.get(url)

    etf_json = response.json()

    etfItemList = etf_json["result"]["etfItemList"]

    df = pd.DataFrame(etfItemList)

    return df

# %%
ETF_list_scraping()
# Out:
# 2022-09-29의 ETP 정보입니다.
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   28400        2         10
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   13945        2        180
# 2     423160           7    KODEX KOFR금리액티브(합성)  100865        2         10
# 3     252670           3       KODEX 200선물인버스2X    3830        5         -5
# 4     133690           4         TIGER 미국나스닥100   73285        2       1060
# ..       ...         ...                    ...     ...      ...        ...
# 617   301400           1         ARIRANG 코스닥150    9665        2         60
# 618   315480           2    KBSTAR 200커뮤니케이션서비스   10945        2         20
# 619   284990           2        KBSTAR 200에너지화학    9265        2         15
# 620   287320           2          KBSTAR 200산업재   10155        2         20
# 621   287310           2        KBSTAR 200경기소비재    9065        2         25
#
#      changeRate       nav  threeMonthEarnRate      quant   amonut  marketSum
# 0          0.04   28443.0            -10.8914    5978248   171672      47300
# 1          1.31   13981.0            -24.2016    2664833    37136      33206
# 2          0.01  100870.0              0.5683      36514     3683      30419
# 3         -0.13    3814.0             23.1139  271306969  1014794      22969
# 4          1.47   73992.0              4.2012     113436     8349      21451
# ..          ...       ...                 ...        ...      ...        ...
# 617        0.62    9801.0            -12.7215       4266       41         19
# 618        0.18   10953.0            -16.6349       1510       16         15
# 619        0.16    9278.0            -15.7176        497        4         11
# 620        0.20   10190.0            -10.6262         15        0          8
# 621        0.28    9082.0             -5.7352          6        0          7
#
# [622 rows x 12 columns]
