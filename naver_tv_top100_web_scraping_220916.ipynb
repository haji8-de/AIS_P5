# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from bs4 import BeautifulSoup
import requests
from datetime import datetime

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'}
url = "https://tv.naver.com/"
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
rank = 1

results = soup.find('div','rank_list').findAll('dt')

#print(response.text)
#print(results.get_text())

print(datetime.today().strftime("%Y년 %m월 %d일의 네이버 TV TOP 100 입니다.\n"))

for result in results:
    print(rank,"위 : ",result.find('tooltip').get_text(),"\n")
    rank += 1
# Out:
# 2022년 09월 17일의 네이버 TV TOP 100 입니다.
#
# 1 위 :  [백브리핑] "이 못된 애"…기자 머리채까지 잡은..
#
# 2 위 :  박치기로 부서지는 러시아군의 '유리 헬멧'?,  ..
#
# 3 위 :  태풍 ‘난마돌’ 초강력으로 발달, 내일 밤부터 ..
#
# 4 위 :  [자막뉴스] 작전 걸려든 러시아군 줄행랑...전..
#
# 5 위 :  ‘넉 달 내릴 비가 3시간 만에’…이탈리아 물폭탄..
#
# 6 위 :  [날씨] 초강력 태풍 '난마돌' 북상... 제주도 ..
#
# 7 위 :  [단독] 범행 8시간 전 현금 인출 시도..."도주 ..
#
# 8 위 :  [예고] 결국 이혼 도장 찍는 부부, 집 나서는 ..
#
# 9 위 :  신당역 살해범 징역 9년 구형에도 불구속..."국..
#
# 10 위 :  [몽르 FLOW] 동아시아 전쟁 고조 전개와 변수 1..
#
# 11 위 :  오 박사의 의미심장한 질문? 오 박사의 뜻 밖의..
#
# 12 위 :  [자막뉴스] 멈출 기미 없는 집값 급락...이젠 ..
#
# 13 위 :  내복인가요? 나이키, 카타르 월드컵 한국 홈 유..
#
# 14 위 :  [12시 날씨] 주말 늦더위…태풍 ‘난마돌’ 내일 ..
#
# 15 위 :  [카지노] 티저 예고편ㅣ디즈니+
#
# 16 위 :  [전체HL] 키움, 롯데와 난타전 끝에 맹추격을 ..
#
# 17 위 :  [단독] "샤워캡, 여자화장실 들어가려고"…신당..
#
# 18 위 :  [영상] 이재명·故 김문기 '호주 출장' 영상 공..
#
# 19 위 :  영빈관 신축 하루만에 철회…민주 "김 여사 발언..
#
# 20 위 :  BLACKPINK - ‘Shut Down’ M/V
#
# 21 위 :  '국민배우' 안성기, 혈액암 투병중
#
# 22 위 :  [날씨] 주말 30도 안팎 늦더위…태풍 '난마돌' ..
#
# 23 위 :  애런 저지가 도전할 수 있는 기록 총정리
#
# 24 위 :  ※늦은 밤 시작된 울음 테러(!)※ 금쪽이 울음은 ..
#
# 25 위 :  넉 달만 맡겼다더니‥2차 작전 PC에서 '김건희.x..
#
# 26 위 :  신당역 스토킹 살해범 구속...'신상공개' 여부 ..
#
# 27 위 :  [날씨] 주말 늦더위 기승...내일부터 제주·영남..
#
# 28 위 :  한미 "北 핵 억제위해 핵 포함 모든 능력 동원"
#
# 29 위 :  [규현 2R 공개] 반전의 반전(°Д°) 충격에 말을 ..
#
# 30 위 :  신문브리핑3 "檢 "이재명, 김문기에 최소 6차례..
#
# 31 위 :  심각한 수준의 금쪽이 울음, 도가 지나친 울음..
#
# 32 위 :  [이슈체크] '496억→2881억+α' 눈덩이처럼 불어..
#
# 33 위 :  신문브리핑2 "'878억 영빈관' 비판 여론에…윤 ..
#
# 34 위 :  [통일로 미래로] 70여 년 만에 열린 금강산 통..
#
# 35 위 :  외계인의 프리킥? | 2002 FIFA 한일 월드컵 #sh..
#
# 36 위 :  황동혁 "이정재 비롯한 배우들 늙을 수 있어, ..
#
# 37 위 :  "회사는 보호해줬나"…혼자 순찰하고 동선 고스..
#
# 38 위 :  [금쪽 속마음] ＂너 때문에 불편해, 너 싫다고!＂..
#
# 39 위 :  [규현 2R] 고막 정화 완💕 추리도 잊게 만드는 ..
#
# 40 위 :  [상암동비디오] 폼생폼사_돌아온 Y2K 패션
#
# 41 위 :  [토요와이드] 영빈관 신축 하루 만에 철회…민주..
#
# 42 위 :  천년고찰 물들인 붉은 상사화…3년 만에 가을꽃 ..
#
# 43 위 :  [날씨] 주말 늦더위...제주·영남 해안 태풍 직..
#
# 44 위 :  한국, 승부치기서 타이완 꺾고 U-18 야구월드컵..
#
# 45 위 :  ‘신당역 살인’ 피의자 구속…“증거인멸·도망 우..
#
# 46 위 :  [단독] 고소 뒤에도 계속된 연락…경찰은 "추가 ..
#
# 47 위 :  [단독 선공개] 본인피셜 비밀 라인(?)의 중심 ..
#
# 48 위 :  [뉴스토리] 고물가&짠테크
#
# 49 위 :  [규현 3R 공개] 춤까지 완벽한 모창능력자들ㅋ..
#
# 50 위 :  신축 없다더니…"영빈관 옮길 거야" 김건희 여사..
#
# 51 위 :  [밀착카메라] 병충해 예방약 믿고 뿌렸는데…배 ..
#
# 52 위 :  푸틴 속 태우는 시진핑? 코로나 핑계로 단체사..
#
# 53 위 :  서울시의원, 스토킹 살인에 "좋아하는데 안 받..
#
# 54 위 :  이제 바뀝니다. 무조건 과태료 날아갑니다!
#
# 55 위 :  [단독] 文정부, 문화재 알고도 러시아에 480억 ..
#
# 56 위 :  '신당역 살인' 이어지는 추모 발걸음..."떠나게..
#
# 57 위 :  [몽르 FLOW] 동아시아 전쟁 고조 전개와 변수 1..
#
# 58 위 :  [자막뉴스] 코스피까지 무너질 위기...'파월 입..
#
# 59 위 :  전여친과 명동 한복판에서 싸운 주원?! 트라우..
#
# 60 위 :  총천연색으로 물든 사격 진지…철원 초대형 꽃밭..
#
# 61 위 :  LA 스팍스 키아나 스미스, 🇰🇷태극마크🇰🇷 위..
#
# 62 위 :  [넷플릭스] 수리남 | 제작기 영상
#
# 63 위 :  [날씨] 주말 늦더위…태풍 영향 영남 · 제주 '많..
#
# 64 위 :  "다 탔네, 전부 다 탔어"…중국 3대 통신사 42층..
#
# 65 위 :  규현 멘붕 그 자체💫 긴장할 수밖에 없는 모창..
#
# 66 위 :  '고무줄' 이전 비용…청와대 문화공간화에 445억..
#
# 67 위 :  금쪽이의 울음 떼가 시작되자 화장실로 가는 엄..
#
# 68 위 :  단 1표 차로 갈린 『규현』편 최종 우승자는?! | ..
#
# 69 위 :  히든싱어7 6회 예고편 - 잔나비의 감성 보컬🎤 ..
#
# 70 위 :  대통령 제도 보완 약속에 법무부도 나섰지만 '..
#
# 71 위 :  ‘나홀로 순찰’ 지하철 역무원…CCTV로 본 아찔 ..
#
# 72 위 :  [단독] 아태협의 '이재명 사전 선거운동 혐의' ..
#
# 73 위 :  [규현 1R 공개] 충격적인 결과(⊙⊙)‼ 진짜 규현..
#
# 74 위 :  [규현 3R] 음원으로도 없는🎼 5명의 규현이 부..
#
# 75 위 :  소송으로 끝맺은 소속사와의 관계..주원의 '피..
#
# 76 위 :  "영빈관 신축은 '국격'"‥"국민들 힘든데 예산 ..
#
# 77 위 :  14호 태풍 '난마돌' 오늘 중 최강력으로 발달…..
#
# 78 위 :  [규현 4R 공개] 움찔하게 만드는 목소리..💿 진..
#
# 79 위 :  모두가 경악한Σ(º ﾛ º๑) 충격적인 규현 2라..
#
# 80 위 :  고주원이 결혼을 무서워하는 이유? 가부장적인 ..
#
# 81 위 :  부산 집값 - 정말 큰일났습니다.#부산부동산
#
# 82 위 :  주호영, 원내대표 선거 출마 선언…영빈관 공방 ..
#
# 83 위 :  [930 날씨] 주말 늦더위…중부 소나기, 제주·남..
#
# 84 위 :  청와대 개방에 또 추가 예산‥내년까지 465억원
#
# 85 위 :  신문브리핑1 ""살아서 퇴근하고 싶다"…신당역 ..
#
# 86 위 :  [단독] 삼성전자도 RE100 선언은 했는데 정작 ..
#
# 87 위 :  [단독] "이재명 압도적 당선 위해"…지역별 하부..
#
# 88 위 :  [자막뉴스] 신당역 살인 사건에 '충격'...즉시 ..
#
# 89 위 :  '무뚝뚝'하고 '까칠'한 고주원? 주원의 5년 차 ..
#
# 90 위 :  ＂배우가 사진도 못 찍어줘?＂ 쏟아지는 악플에 ..
#
# 91 위 :  [규현 4R] 달달한 고백송😍 〈내 마음이 움찔했..
#
# 92 위 :  한국선수 보러 갔다 벌어진 충격적인 축구장 집..
#
# 93 위 :  나를 한심하게 보는 아버지의 눈빛... 마음의 ..
#
# 94 위 :  일동 경악(⊙o⊙) 감정 뚝딱이 고주원의 연애 상..
#
# 95 위 :  1400원 턱밑서 '도시락 폭탄'…한미 통화스와프 ..
#
# 96 위 :  [단독] '정부 공동지분 빌딩' 리모델링에 나랏..
#
# 97 위 :  공감은 ★지능순★ 이성형 인간 주원에게 필요한 ..
#
# 98 위 :  '대무가' 2차 예고편
#
# 99 위 :  온화하고 수용적인 금쪽이 아빠, 금쪽이의 떼와..
#
# 100 위 :  IVE 아이브 'After LIKE' MV
